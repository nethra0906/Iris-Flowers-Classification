# %% [markdown]
# # Loading Data & Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('C:\\Users\\Nethr\\Data Science Projects\\IRIS.csv')

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print(iris['species'].value_counts()) #count the number of occurrences of each unique value in the 'species' column of the 'iris' dataset.
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
print(iris.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.groupby('species').mean()) #calculate the mean of each column in the 'iris' dataset, grouped by the 'species' column.
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species')
plt.title('Petal Length vs Petal Width')
plt.show()

# %%
sub_setosa=iris[iris['species']=='Iris-setosa']
plt.scatter(sub_setosa['sepal_length'], sub_setosa['sepal_width'], marker='o', color='cyan')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Width versus Length for Setosa species')
plt.show()

# %%
sub_versicolor=iris[iris['species']=='Iris-versicolor']
plt.scatter(sub_versicolor['sepal_length'], sub_versicolor['sepal_width'], marker='o', color='violet')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Width versus Length for Versicolor species')
plt.show()

# %%
sub_virginica=iris[iris['species']=='Iris-virginica']
plt.scatter(sub_virginica['sepal_length'], sub_virginica['sepal_width'], marker='o', color='r')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Width versus Length for Virginica species')
plt.show()

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
X = iris.drop(columns='species', axis=1)
y = iris['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2, stratify=y)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (135, 4) (15, 4) (135,) (15,)

# %%
from sklearn.model_selection import train_test_split
X=iris.drop(['species'], axis=1)
y=iris['species']
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.5, shuffle=True,random_state=100)

# %%
from sklearn.svm import SVC
model=SVC(C=1, kernel='rbf', tol=0.001)
print(model.fit(X_train, y_train))
# Out:
# SVC(C=1)

# %%
pred=model.predict(X_test)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print(confusion_matrix(y_test, pred))
print('\n')
print(classification_report(y_test, pred))
print('\n')
print('Accuracy score is: ', accuracy_score(y_test, pred))
# Out:
# [[28  0  0]
#  [ 0 17  0]
#  [ 0  5 25]]
#
#
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        28
# Iris-versicolor       0.77      1.00      0.87        17
#  Iris-virginica       1.00      0.83      0.91        30
#
#        accuracy                           0.93        75
#       macro avg       0.92      0.94      0.93        75
#    weighted avg       0.95      0.93      0.93        75
#
#
#
# Accuracy score is:  0.9333333333333333

# %% [markdown]
# # Accuracy Score Prediction using Logistic Regression

# %%
y_train_logistic_predicted = logistic_model.predict(X_train)
acc1 = accuracy_score(y_train, y_train_logistic_predicted)
print(acc1)
# Out:
# 0.96

# %%
y_test_logistic_predicted = logistic_model.predict(X_test)
acc2 = accuracy_score(y_test, y_test_logistic_predicted)
print(acc2)
# Out:
# 0.9866666666666667

# %% [markdown]
# # Accuracy Score Prediction using Decision Tree Classification

# %%
y_train_tree_predicted = decision_model.predict(X_train)
acc3 = accuracy_score(y_train, y_train_tree_predicted)
print(acc3)
# Out:
# 1.0

# %%
y_test_tree_predicted = decision_model.predict(X_test)
acc4 = accuracy_score(y_test, y_test_tree_predicted)
print(acc4)
# Out:
# 1.0
